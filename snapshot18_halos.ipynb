# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
with open(r'C:/Users/satvi/PhD_thesis/halolist_018.dat', 'rb') as file:
    ngroups_tot = np.fromfile(file, dtype=np.int32, count=1)[0]
    
    groupCM_x = np.fromfile(file, dtype=np.float32, count=ngroups_tot)
    groupCM_y = np.fromfile(file, dtype=np.float32, count=ngroups_tot)
    groupCM_z = np.fromfile(file, dtype=np.float32, count=ngroups_tot)
    mass_gas = np.fromfile(file, dtype=np.float32, count=ngroups_tot)
    mass_dm = np.fromfile(file, dtype=np.float32, count=ngroups_tot)
    mass_stars = np.fromfile(file, dtype=np.float32, count=ngroups_tot)

# %%
plt.scatter(groupCM_x,groupCM_y,s=0.0001)

# %%
np.logspace(np.log10(min(mass_dm)),np.log10(max(mass_dm)),51)
# Out:
# array([1.10027208e+09, 1.34497130e+09, 1.64409134e+09, 2.00973533e+09,
#        2.45669811e+09, 3.00306489e+09, 3.67094300e+09, 4.48735642e+09,
#        5.48533923e+09, 6.70527225e+09, 8.19651695e+09, 1.00194127e+10,
#        1.22477184e+10, 1.49715966e+10, 1.83012621e+10, 2.23714414e+10,
#        2.73468237e+10, 3.34287253e+10, 4.08632346e+10, 4.99511701e+10,
#        6.10602518e+10, 7.46399802e+10, 9.12398244e+10, 1.11531454e+11,
#        1.36335919e+11, 1.66656868e+11, 2.03721160e+11, 2.49028507e+11,
#        3.04412156e+11, 3.72113062e+11, 4.54870571e+11, 5.56033253e+11,
#        6.79694397e+11, 8.30857635e+11, 1.01563940e+12, 1.24151641e+12,
#        1.51762821e+12, 1.85514694e+12, 2.26772945e+12, 2.77206982e+12,
#        3.38857490e+12, 4.14218999e+12, 5.06340819e+12, 6.18950424e+12,
#        7.56604273e+12, 9.24872177e+12, 1.13056267e+13, 1.38199848e+13,
#        1.68935332e+13, 2.06506352e+13, 2.52433123e+13])

# %%
np.log10(min(mass_dm))
# Out:
# 9.0415
